# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans

# %%
#DOWNLOAD DATA KENDARAAN_TRAIN
# !gdown --id 1VAFV-soyTtaUx8k1sWR1kkCtuDA_yX3V
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1VAFV-soyTtaUx8k1sWR1kkCtuDA_yX3V
# To: /content/kendaraan_train.xlsx
# 100% 14.3M/14.3M [00:00<00:00, 127MB/s]

# %%
#BACA DATA KENDARAAN_TRAIN
data1 = pd.read_excel("kendaraan_train.xlsx")
data1
# Out:
#             id Jenis_Kelamin  ...  Lama_Berlangganan  Tertarik
# 0            1        Wanita  ...               97.0         0
# 1            2          Pria  ...              158.0         0
# 2            3           NaN  ...              119.0         0
# 3            4        Wanita  ...               63.0         0
# 4            5          Pria  ...              194.0         0
# ...        ...           ...  ...                ...       ...
# 285826  285827        Wanita  ...              217.0         0
# 285827  285828        Wanita  ...               50.0         0
# 285828  285829        Wanita  ...              226.0         0
# 285829  285830          Pria  ...              270.0         0
# 285830  285831          Pria  ...               44.0         0
#
# [285831 rows x 12 columns]

# %%
#DOWNLOAD KENDARAAN_TEST
# !gdown --id 1-tLY7LwlMwG7Kxk3u58J9gDNhSmfCIpa
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-tLY7LwlMwG7Kxk3u58J9gDNhSmfCIpa
# To: /content/kendaraan_test.xlsx
# 100% 2.13M/2.13M [00:00<00:00, 68.4MB/s]

# %%
#BACA DATA KENDARAAN_TEST
data2 = pd.read_excel("kendaraan_test.xlsx")
data2
# Out:
#       Jenis_Kelamin  Umur  SIM  ...  Kanal_Penjualan  Lama_Berlangganan Tertarik
# 0            Wanita    22    1  ...              124                 71        1
# 1              Pria    54    1  ...              124                198        0
# 2            Wanita    24    1  ...              124                171        0
# 3            Wanita    78    1  ...               26                208        1
# 4            Wanita    45    1  ...               26                228        0
# ...             ...   ...  ...  ...              ...                ...      ...
# 47634          Pria    41    1  ...               78                 20        0
# 47635          Pria    39    1  ...              124                200        0
# 47636          Pria    33    1  ...              152                152        0
# 47637        Wanita    71    1  ...               25                226        0
# 47638        Wanita    32    1  ...               26                202        0
#
# [47639 rows x 11 columns]

# %%
#INFO DATA KENDARAAN_TRAIN
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 285831 entries, 0 to 285830
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 285831 non-null  int64
#  1   Jenis_Kelamin      271391 non-null  object
#  2   Umur               271617 non-null  float64
#  3   SIM                271427 non-null  float64
#  4   Kode_Daerah        271525 non-null  float64
#  5   Sudah_Asuransi     271602 non-null  float64
#  6   Umur_Kendaraan     271556 non-null  object
#  7   Kendaraan_Rusak    271643 non-null  object
#  8   Premi              271262 non-null  float64
#  9   Kanal_Penjualan    271532 non-null  float64
#  10  Lama_Berlangganan  271839 non-null  float64
#  11  Tertarik           285831 non-null  int64
# dtypes: float64(7), int64(2), object(3)
# memory usage: 26.2+ MB

# %%
#INFO DATA KENDARAAN_TEST
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47639 entries, 0 to 47638
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Jenis_Kelamin      47639 non-null  object
#  1   Umur               47639 non-null  int64
#  2   SIM                47639 non-null  int64
#  3   Kode_Daerah        47639 non-null  int64
#  4   Sudah_Asuransi     47639 non-null  int64
#  5   Umur_Kendaraan     47639 non-null  object
#  6   Kendaraan_Rusak    47639 non-null  object
#  7   Premi              47639 non-null  int64
#  8   Kanal_Penjualan    47639 non-null  int64
#  9   Lama_Berlangganan  47639 non-null  int64
#  10  Tertarik           47639 non-null  int64
# dtypes: int64(8), object(3)
# memory usage: 4.0+ MB

# %%
#DESCRIBE SEMUA DATA1
data1.describe()
# Out:
#                   id           Umur  ...  Lama_Berlangganan       Tertarik
# count  285831.000000  271617.000000  ...      271839.000000  285831.000000
# mean   142916.000000      38.844336  ...         154.286302       0.122471
# std     82512.446734      15.522487  ...          83.694910       0.327830
# min         1.000000      20.000000  ...          10.000000       0.000000
# 25%     71458.500000      25.000000  ...          82.000000       0.000000
# 50%    142916.000000      36.000000  ...         154.000000       0.000000
# 75%    214373.500000      49.000000  ...         227.000000       0.000000
# max    285831.000000      85.000000  ...         299.000000       1.000000
#
# [8 rows x 9 columns]

# %%
#MELIHAT UKURAN DATA1
data1.shape
# Out:
# (285831, 12)

# %%
#CEK JUMLAH NULL DALAM TIAP KOLOM
check_null = data1.isnull().sum()
print(check_null)
# Out:
# id                       0
# Jenis_Kelamin        14440
# Umur                 14214
# SIM                  14404
# Kode_Daerah          14306
# Sudah_Asuransi       14229
# Umur_Kendaraan       14275
# Kendaraan_Rusak      14188
# Premi                14569
# Kanal_Penjualan      14299
# Lama_Berlangganan    13992
# Tertarik                 0
# dtype: int64

# %%
#CEK NILAI NULL SETIAP KOLOM
heatmap = sns.heatmap(data1.isnull())

# %%
#MENAMPILKAN JUMLAH DATA YANG DUPLIKAT
dupl = data1.duplicated()
print('Number of duplicate rows = %d' % (dupl.sum()))
# Out:
# Number of duplicate rows = 0

# %%
#CEK OUTLIER
data1.boxplot(figsize=[15,5])
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# DATA CLEAN(PEMBERSIHAN DATA)

# %%
#SPLIT DATA
data1_x = data1.iloc[:, :11]
data1_y = data1['Tertarik']
print('Data frame x : ')
print(data1_x.shape)
print('Data frame y : ')
print(data1_y.shape)
# Out:
# Data frame x :
# (285831, 11)
# Data frame y :
# (285831,)

# %%
data1_y.head(5)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Tertarik, dtype: int64

# %%
data1_x.head()
# Out:
#    id Jenis_Kelamin  Umur  ...    Premi  Kanal_Penjualan  Lama_Berlangganan
# 0   1        Wanita  30.0  ...  28029.0            152.0               97.0
# 1   2          Pria  48.0  ...  25800.0             29.0              158.0
# 2   3           NaN  21.0  ...  32733.0            160.0              119.0
# 3   4        Wanita  58.0  ...   2630.0            124.0               63.0
# 4   5          Pria  50.0  ...  34857.0             88.0              194.0
#
# [5 rows x 11 columns]

# %%
#DROP NULL DATAFRAME
data1_x.dropna(inplace = True)
data1_x.shape
# Out:
# (171068, 11)

# %%
#HEATMAP CEK NILAI NULL SETIAP KOLOM
heatmap = sns.heatmap(data1_x.isnull())

# %%
data1_x.to_excel(r'kendaraan_train.xlsx', index =  False)

# %%
data1_x
# Out:
#             id Jenis_Kelamin  Umur  ...    Premi  Kanal_Penjualan  Lama_Berlangganan
# 0            1        Wanita  30.0  ...  28029.0            152.0               97.0
# 1            2          Pria  48.0  ...  25800.0             29.0              158.0
# 3            4        Wanita  58.0  ...   2630.0            124.0               63.0
# 5            6          Pria  21.0  ...  22735.0            152.0              171.0
# 8            9        Wanita  20.0  ...  30786.0            160.0               31.0
# ...        ...           ...   ...  ...      ...              ...                ...
# 285826  285827        Wanita  23.0  ...  25988.0            152.0              217.0
# 285827  285828        Wanita  21.0  ...  44686.0            152.0               50.0
# 285828  285829        Wanita  23.0  ...  49751.0            152.0              226.0
# 285829  285830          Pria  68.0  ...  30503.0            124.0              270.0
# 285830  285831          Pria  45.0  ...  36480.0             26.0               44.0
#
# [171068 rows x 11 columns]

# %%
data1_x.dtypes
# Out:
# id                     int64
# Jenis_Kelamin         object
# Umur                 float64
# SIM                  float64
# Kode_Daerah          float64
# Sudah_Asuransi       float64
# Umur_Kendaraan        object
# Kendaraan_Rusak       object
# Premi                float64
# Kanal_Penjualan      float64
# Lama_Berlangganan    float64
# dtype: object

# %%
print(data1_x['Jenis_Kelamin'].unique())
print(data1_x['Umur_Kendaraan'].unique())
print(data1_x['Kendaraan_Rusak'].unique())
# Out:
# ['Wanita' 'Pria']
# ['< 1 Tahun' '> 2 Tahun' '1-2 Tahun']
# ['< 1 Tahun' 'Pernah' 'Tidak']

# %%
#LABEL MAPPING
codes = {
    'Wanita'    : 0,
    'Pria'      : 1,
    '< 1 Tahun' : 0,
    '> 2 Tahun' : 2,
    '1-2 Tahun' : 1,
    'Pernah'    : 1,
    'Tidak'     : 0,
    
} 
#KATEGORI MAPPING
data1_x = data1_x.replace({'Jenis_Kelamin':codes,'Umur_Kendaraan':codes,'Kendaraan_Rusak':codes})
data1_x.head()
# Out:
#    id  Jenis_Kelamin  Umur  ...    Premi  Kanal_Penjualan  Lama_Berlangganan
# 0   1              0  30.0  ...  28029.0            152.0               97.0
# 1   2              1  48.0  ...  25800.0             29.0              158.0
# 3   4              0  58.0  ...   2630.0            124.0               63.0
# 5   6              1  21.0  ...  22735.0            152.0              171.0
# 8   9              0  20.0  ...  30786.0            160.0               31.0
#
# [5 rows x 11 columns]

# %%
data1_x.to_excel(r'kendaraaan_notchar.xlsx', index = False)

# %%
#CEK OUTLIER
data1_x.boxplot(figsize = [15,5])

# %%
#HILANGKAN OUTLIERS USING Z-Score
Q1 = data1_x.quantile(0.25)
Q3 = data1_x.quantile(0.75)
IQR = Q3 - Q1

data1_x = data1_x.loc[~((data1_x < (Q1 - 1.5 * IQR)).any(axis=1)|(data1_x > (Q3 + 1.5 * IQR)).any(axis=1))].dropna()
data1_x.reset_index(drop=True, inplace=True)
data1_x.boxplot()

# %%
data1_x.shape
# Out:
# (166064, 11)

# %%
data1_x.to_excel(r'kendaraan_n-outlier.xlsx', index = False)

# %%
#NORMALISASI MENGGUNAKAN MINMAXSCALER
scaler = MinMaxScaler()
data1_x = scaler.fit_transform(data1_x)
pd.DataFrame(data1_x)
# Out:
#               0    1         2    3   ...   7         8         9         10
# 0       0.000000  0.0  0.153846  0.0  ...  0.0  0.429632  0.932099  0.301038
# 1       0.000003  1.0  0.430769  0.0  ...  1.0  0.391928  0.172840  0.512111
# 2       0.000010  0.0  0.584615  0.0  ...  0.0  0.000000  0.759259  0.183391
# 3       0.000017  1.0  0.015385  0.0  ...  0.0  0.340083  0.932099  0.557093
# 4       0.000028  0.0  0.000000  0.0  ...  0.0  0.476268  0.981481  0.072664
# ...          ...  ...       ...  ...  ...  ...       ...       ...       ...
# 166059  0.999986  0.0  0.046154  0.0  ...  0.0  0.395108  0.932099  0.716263
# 166060  0.999990  0.0  0.015385  0.0  ...  0.0  0.711391  0.932099  0.138408
# 166061  0.999993  0.0  0.046154  0.0  ...  0.0  0.797067  0.932099  0.747405
# 166062  0.999997  1.0  0.738462  0.0  ...  0.0  0.471481  0.759259  0.899654
# 166063  1.000000  1.0  0.384615  0.0  ...  1.0  0.572584  0.154321  0.117647
#
# [166064 rows x 11 columns]

# %% [markdown]
# CLUSTERING K-MEANS

# %%
#COMBINE KOLOM DAN BUAT X DAN Y
pca       = PCA(n_components = 2)
pca_data  = pca.fit_transform(data1_x)
pca_data1 = pd.DataFrame(data = pca_data, columns = ['PCA X', 'PCA Y'])
pca_data1.shape
# Out:
# (166064, 2)

# %%
pca_data1.head()
# Out:
#       PCA X     PCA Y
# 0 -0.902543  0.417764
# 1  0.980004 -0.425090
# 2 -0.037299  0.483329
# 3 -0.761632 -0.529836
# 4 -0.940026  0.436631

# %%
pca_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166064 entries, 0 to 166063
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   PCA X   166064 non-null  float64
#  1   PCA Y   166064 non-null  float64
# dtypes: float64(2)
# memory usage: 2.5 MB

# %%
#MELAKUKAN PLOTTING BERDASARKAN X DAN Y
sns.scatterplot(x = 'PCA X', y = 'PCA Y', data = pca_data1)

# %%
# Inisiasi Variable
K = 2               # jumlah centeroid (tertarik / tidak tertarik)
iterations = 2    # jumlah perulangannya

pca_data1.values.shape
# Out:
# (166064, 2)

# %%
# membuat centeroid
Centroids=np.array([]).reshape(pca_data1.values.shape[1],0) 
Centroids
# Out:
# array([], shape=(2, 0), dtype=float64)

# %%
# memilih titik centeroid secara acak
for i in range(K):
    rand=np.random.randint(0,pca_data1.values.shape[0]-1)
    Centroids=np.c_[Centroids,pca_data1.values[rand]]

# %%
for i in range(iterations):
    # matrix for calculate euclidian distance
    EuclidianDistance=np.array([]).reshape(pca_data1.values.shape[0],0)
    for i in range(K):
        tempDist=np.sum((pca_data1-Centroids[:,i])**2,axis=1)
        EuclidianDistance=np.c_[EuclidianDistance,tempDist]
    C=np.argmin(EuclidianDistance,axis=1)+1

    temp={}
    for i in range(K):
        temp[i+1]=np.array([]).reshape(2,0)

    for i in range(pca_data1.values.shape[0]):
        temp[C[i]]=np.c_[temp[C[i]],pca_data1.values[i]]

    for i in range(K):
        temp[i+1]=temp[i+1].T

    for i in range(K):
         Centroids[:,i]=np.mean(temp[i+1],axis=0)
    output = temp

# %%
colors = [
     'yellow',
     'blue'
]
labels=[
    'tertarik','tidak tertarik']
colors
# Out:
# ['yellow', 'blue']

# %%
# melakukan ploting dengan scatter beserta labeling
for k in range(K):
    plt.scatter(output[k+1][:,0],output[k+1][:,1],c=colors[k],label=labels[k])
    
plt.scatter(Centroids[0,:],Centroids[1,:],s=10,c='black',label='Centroids')
plt.legend()
plt.show()

# %% [markdown]
# DATA CLUSTERING K-MEANS LIBRARY

# %%
# Fitting K-Means to the dataset
kmeans = KMeans(n_clusters = 2, max_iter = 150)
y_kmeans = kmeans.fit_predict(pca_data1)

# %%
y_kmeans
# Out:
# array([0, 1, 1, ..., 0, 0, 1], dtype=int32)

# %%
# Visualising the clusters
for i in range(K):
    plt.scatter(pca_data1.values[y_kmeans == i, 0], pca_data1.values[y_kmeans == i, 1], c=colors[i],label=labels[i])

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=10,c='violet',label='Centroids')

plt.title('Clusters of KMeans')
plt.legend()
plt.show()

# %% [markdown]
# ----------------BATASSS---------
